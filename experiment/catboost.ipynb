# %%
import numpy as np
import pandas as pd
import catboost as cat
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
 
pd.set_option('precision', 5)
pd.set_option('display.float_format', lambda x: '%.5f' % x) 
pd.options.display.max_rows = 200

# %%
train_df = pd.read_csv('data/train/train_tag.csv')
test_df = pd.read_csv('data/test/test_tag_b.csv')
print(train_df.shape)
print(test_df.shape)
# Out:
# (39923, 43)
# (4000, 42)

# %%
# beh_pageno_cnt = pd.read_csv('data/beh_pageno_target_encoding.csv')
# print(beh_pageno_cnt.shape)
# merge_train_data = pd.merge(train_df, beh_pageno_cnt, on='id', how='left')
# print(merge_train_data.shape)
# merge_test_data = pd.merge(test_df, beh_pageno_cnt, on='id', how='left')
# print(merge_test_data.shape)

# %%
trd_cnt = pd.read_csv('data/trd_cnt.csv')
print(trd_cnt.shape)
# Out:
# (35183, 6)

# %%
# merge_train_data = pd.merge(merge_train_data, trd_cnt, on='id', how='left')
# print(merge_train_data.shape)
# merge_test_data = pd.merge(merge_test_data, trd_cnt, on='id', how='left')
# print(merge_test_data.shape)
merge_train_data = pd.merge(train_df, trd_cnt, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(test_df, trd_cnt, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (39923, 48)
# (4000, 47)

# %%
trd_amt = pd.read_csv('data/trd_amount.csv')
print(trd_amt.shape)
# Out:
# (35183, 7)

# %%
merge_train_data = pd.merge(merge_train_data, trd_amt, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, trd_amt, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (39923, 54)
# (4000, 53)

# %%
trd_cod1_cnt = pd.read_csv('data/trd_cod1_cnt.csv')
print(trd_cod1_cnt.shape)
merge_train_data = pd.merge(merge_train_data, trd_cod1_cnt, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, trd_cod1_cnt, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (35183, 8)
# (39923, 61)
# (4000, 60)

# %%
trd_flg3_cnt = pd.read_csv('data/trd_flg3_cnt.csv')
print(trd_flg3_cnt.shape)
merge_train_data = pd.merge(merge_train_data, trd_flg3_cnt, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, trd_flg3_cnt, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (35183, 8)
# (39923, 68)
# (4000, 67)

# %%
beh_feature_train_pred = pd.read_csv('data/beh_feature_train_pred.csv')
beh_feature_test_pred = pd.read_csv('data/beh_feature_test_pred.csv')
print(beh_feature_train_pred.shape)
print(beh_feature_test_pred.shape)
merge_train_data = pd.merge(merge_train_data, beh_feature_train_pred, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, beh_feature_test_pred, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (11913, 2)
# (1232, 2)
# (39923, 69)
# (4000, 68)

# %%
beh_feature_train_pred_mean = pd.read_csv('data/beh_feature_train_pred_mean.csv')
beh_feature_test_pred_mean = pd.read_csv('data/beh_feature_test_pred_mean.csv')
merge_train_data = pd.merge(merge_train_data, beh_feature_train_pred_mean, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, beh_feature_test_pred_mean, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (39923, 70)
# (4000, 69)

# %%
beh_feature_train_pred_sum = pd.read_csv('data/beh_feature_train_pred_sum.csv')
beh_feature_test_pred_sum = pd.read_csv('data/beh_feature_test_pred_sum.csv')
merge_train_data = pd.merge(merge_train_data, beh_feature_train_pred_sum, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, beh_feature_test_pred_sum, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (39923, 71)
# (4000, 70)

# %%
trd_feature_train_pred = pd.read_csv('data/trd_feature_train_pred.csv')
trd_feature_test_pred = pd.read_csv('data/trd_feature_test_pred.csv')
merge_train_data = pd.merge(merge_train_data, trd_feature_train_pred, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, trd_feature_test_pred, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (39923, 72)
# (4000, 71)

# %%
trd_feature_train_pred_mean = pd.read_csv('data/trd_feature_train_pred_mean.csv')
trd_feature_test_pred_mean = pd.read_csv('data/trd_feature_test_pred_mean.csv')
merge_train_data = pd.merge(merge_train_data, trd_feature_train_pred_mean, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, trd_feature_test_pred_mean, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (39923, 73)
# (4000, 72)

# %%
trd_feature_train_pred_sum = pd.read_csv('data/trd_feature_train_pred_sum.csv')
trd_feature_test_pred_sum = pd.read_csv('data/trd_feature_test_pred_sum.csv')
merge_train_data = pd.merge(merge_train_data, trd_feature_train_pred_sum, on='id', how='left')
print(merge_train_data.shape)
merge_test_data = pd.merge(merge_test_data, trd_feature_test_pred_sum, on='id', how='left')
print(merge_test_data.shape)
# Out:
# (39923, 74)
# (4000, 73)

# %%
merge_train_data.isnull().sum()
# Out:
# id                                     0
# flag                                   0
# gdr_cd                                 0
# age                                    0
# mrg_situ_cd                            0
# edu_deg_cd                         12436
# acdm_deg_cd                            1
# deg_cd                             20963
# job_year                               0
# ic_ind                                 0
# fr_or_sh_ind                           0
# dnl_mbl_bnk_ind                        0
# dnl_bind_cmb_lif_ind                   0
# hav_car_grp_ind                        0
# hav_hou_grp_ind                        0
# l6mon_agn_ind                          0
# frs_agn_dt_cnt                         0
# vld_rsk_ases_ind                       0
# fin_rsk_ases_grd_cd                    0
# confirm_rsk_ases_lvl_typ_cd            0
# cust_inv_rsk_endu_lvl_cd               0
# l6mon_daim_aum_cd                      0
# tot_ast_lvl_cd                         0
# pot_ast_lvl_cd                         0
# bk1_cur_year_mon_avg_agn_amt_cd        0
# l12mon_buy_fin_mng_whl_tms             0
# l12_mon_fnd_buy_whl_tms                0
# l12_mon_insu_buy_whl_tms               0
# l12_mon_gld_buy_whl_tms                0
# loan_act_ind                           0
# pl_crd_lmt_cd                          0
# ovd_30d_loan_tot_cnt                   0
# his_lng_ovd_day                        0
# hld_crd_card_grd_cd                    0
# crd_card_act_ind                       0
# l1y_crd_card_csm_amt_dlm_cd            0
# atdd_type                          23657
# perm_crd_lmt_cd                        0
# cur_debit_cnt                          0
# cur_credit_cnt                         0
# cur_debit_min_opn_dt_cnt               0
# cur_credit_min_opn_dt_cnt              0
# cur_debit_crd_lvl                      0
# flg1_trd_cnt_B                      7930
# flg1_trd_cnt_C                      7930
# trd_cnt                             7930
# flg1_trd_cnt_B_precent              7930
# flg1_trd_cnt_C_precent              7930
# cny_trx_amt_B                      10730
# cny_trx_amt_C                       9821
# trx_amt_balance                    12621
# trx_total_amount                   12621
# cny_trx_amt_B_percent              12621
# cny_trx_amt_C_percent              12621
# trx_cod1_1_cnt                     11342
# trx_cod1_2_cnt                     21401
# trx_cod1_3_cnt                     11540
# trx_cod1_cnt                       24596
# trx_cod1_cnt_1_percent             24596
# trx_cod1_cnt_2_percent             24596
# trx_cod1_cnt_3_percent             24596
# trx_flg3_A_cnt                      7930
# trx_flg3_B_cnt                      7930
# trx_flg3_C_cnt                      7930
# trd_flg3_cnt                        7930
# trd_flg3_A_percent                  7930
# trd_flg3_B_percent                  7930
# trd_flg3_C_percent                  7930
# beh_pred                           28010
# beh_pred_mean                      28010
# beh_pred_sum                       28010
# trd_pred                            7930
# trd_pred_mean                       7930
# trd_pred_sum                        7930
# dtype: int64

# %%
merge_test_data.isnull().sum()
# Out:
# id                                    0
# gdr_cd                                0
# age                                   0
# mrg_situ_cd                           0
# edu_deg_cd                         1247
# acdm_deg_cd                           0
# deg_cd                             2069
# job_year                              0
# ic_ind                                0
# fr_or_sh_ind                          0
# dnl_mbl_bnk_ind                       0
# dnl_bind_cmb_lif_ind                  0
# hav_car_grp_ind                       0
# hav_hou_grp_ind                       0
# l6mon_agn_ind                         0
# frs_agn_dt_cnt                        0
# vld_rsk_ases_ind                      0
# fin_rsk_ases_grd_cd                   0
# confirm_rsk_ases_lvl_typ_cd           0
# cust_inv_rsk_endu_lvl_cd              0
# l6mon_daim_aum_cd                     0
# tot_ast_lvl_cd                        0
# pot_ast_lvl_cd                        0
# bk1_cur_year_mon_avg_agn_amt_cd       0
# l12mon_buy_fin_mng_whl_tms            0
# l12_mon_fnd_buy_whl_tms               0
# l12_mon_insu_buy_whl_tms              0
# l12_mon_gld_buy_whl_tms               0
# loan_act_ind                          0
# pl_crd_lmt_cd                         0
# ovd_30d_loan_tot_cnt                  0
# his_lng_ovd_day                       0
# hld_crd_card_grd_cd                   0
# crd_card_act_ind                      0
# l1y_crd_card_csm_amt_dlm_cd           0
# atdd_type                          2356
# perm_crd_lmt_cd                       0
# cur_debit_cnt                         0
# cur_credit_cnt                        0
# cur_debit_min_opn_dt_cnt              0
# cur_credit_min_opn_dt_cnt             0
# cur_debit_crd_lvl                     0
# flg1_trd_cnt_B                      810
# flg1_trd_cnt_C                      810
# trd_cnt                             810
# flg1_trd_cnt_B_precent              810
# flg1_trd_cnt_C_precent              810
# cny_trx_amt_B                      1046
# cny_trx_amt_C                       972
# trx_amt_balance                    1208
# trx_total_amount                   1208
# cny_trx_amt_B_percent              1208
# cny_trx_amt_C_percent              1208
# trx_cod1_1_cnt                     1105
# trx_cod1_2_cnt                     2137
# trx_cod1_3_cnt                     1139
# trx_cod1_cnt                       2428
# trx_cod1_cnt_1_percent             2428
# trx_cod1_cnt_2_percent             2428
# trx_cod1_cnt_3_percent             2428
# trx_flg3_A_cnt                      810
# trx_flg3_B_cnt                      810
# trx_flg3_C_cnt                      810
# trd_flg3_cnt                        810
# trd_flg3_A_percent                  810
# trd_flg3_B_percent                  810
# trd_flg3_C_percent                  810
# beh_pred                           2768
# beh_pred_mean                      2768
# beh_pred_sum                       2768
# trd_pred                            810
# trd_pred_mean                       810
# trd_pred_sum                        810
# dtype: int64

# %%
train_df = merge_train_data
test_df = merge_test_data

# %%
test_df
# Out:
#            id gdr_cd  age mrg_situ_cd edu_deg_cd acdm_deg_cd deg_cd job_year  \
# 0     U1E63A3      M   40           B          C          31    NaN        1
# 1     U3EC77F      M   46           A          C          31    NaN        3
# 2     U27DC0C      M   42           B          F           G    NaN        3
# 3     U3FAAAC      F   35           B          B          30    NaN        5
# 4     U04EA0B      M   34           A          F           G    NaN        9
# ...       ...    ...  ...         ...        ...         ...    ...      ...
# 3995  U0FBFE2      F   58           B          B          30      A       29
# 3996  U506AD2      M   50           B          C          31      ~       25
# 3997  U287B33      M   39           A          Z           Z      ~        0
# 3998  U15134F      M   34           A          B          30      ~        2
# 3999  U41D5EB      M   63           B          C          31    NaN        0
#
#      ic_ind fr_or_sh_ind  ... trd_flg3_cnt trd_flg3_A_percent  \
# 0         0            1  ...     31.00000            0.00000
# 1         0            0  ...          nan                nan
# 2         0            0  ...     34.00000            0.38235
# 3         0            1  ...    100.00000            1.00000
# 4         0            0  ...    132.00000            0.89394
# ...     ...          ...  ...          ...                ...
# 3995      0            0  ...      6.00000            1.00000
# 3996      0            0  ...      3.00000            1.00000
# 3997      1            1  ...      5.00000            1.00000
# 3998      0            0  ...     10.00000            0.50000
# 3999      0            0  ...          nan                nan
#
#      trd_flg3_B_percent trd_flg3_C_percent beh_pred beh_pred_mean  \
# 0               1.00000            0.00000      nan           nan
# 1                   nan                nan      nan           nan
# 2               0.61765            0.00000  0.23599       0.15978
# 3               0.00000            0.00000  0.23575       0.15320
# 4               0.07576            0.03030  0.19327       0.15237
# ...                 ...                ...      ...           ...
# 3995            0.00000            0.00000      nan           nan
# 3996            0.00000            0.00000  0.16572       0.12955
# 3997            0.00000            0.00000  0.16151       0.14973
# 3998            0.50000            0.00000  0.16091       0.13766
# 3999                nan                nan      nan           nan
#
#      beh_pred_sum trd_pred trd_pred_mean trd_pred_sum
# 0             nan  0.39351       0.25660      7.95464
# 1             nan      nan           nan          nan
# 2        10.86477  0.37167       0.15335      5.21401
# 3         9.95801  0.33339       0.14751     14.75058
# 4        20.41699  0.45063       0.15319     20.22057
# ...           ...      ...           ...          ...
# 3995          nan  0.20418       0.13091      0.78546
# 3996      3.23887  0.12773       0.12422      0.37265
# 3997      2.24594  0.21774       0.12836      0.64179
# 3998      2.47794  0.38324       0.17644      1.76435
# 3999          nan      nan           nan          nan
#
# [4000 rows x 73 columns]

# %%
def age_cd(age):
    age_str = ""
    if age >= 18 and age < 24 :
        age_str = "18-24"
    elif age >= 24 and age < 30 :
        age_str = "24-30"
    elif age >= 30 and age < 40 :
        age_str = "30-40"
    elif age >= 40 and age < 50 :
        age_str = "40-50"
    elif age >= 50 and age < 60 :
        age_str = "50-60"
    elif age >= 60 :
        age_str = ">=60"
    else :
        age_str = "<18"
    return age_str

# %%
train_df['age']=train_df['age'].apply(lambda x : age_cd(x))
test_df['age']=test_df['age'].apply(lambda x : age_cd(x))

# %%
train_df['age&gdr'] = train_df['age'] + train_df['gdr_cd']
test_df['age&gdr'] = test_df['age'] + test_df['gdr_cd']
train_df['age&gdr']
# Out:
# 0        40-50M
# 1        30-40M
# 2        50-60M
# 3        40-50F
# 4        40-50F
#           ...
# 39918    24-30M
# 39919    40-50M
# 39920    24-30M
# 39921    30-40M
# 39922    30-40M
# Name: age&gdr, Length: 39923, dtype: object

# %%
train_target = train_df['flag']
test_id = test_df['id']
train_df.drop(['flag','id'], axis = 1, inplace=True)
test_df.drop(['id'], axis = 1, inplace=True)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (39923, 73)
# (4000, 73)

# %%
train_df.columns
# Out:
# Index(['gdr_cd', 'age', 'mrg_situ_cd', 'edu_deg_cd', 'acdm_deg_cd', 'deg_cd',
#        'job_year', 'ic_ind', 'fr_or_sh_ind', 'dnl_mbl_bnk_ind',
#        'dnl_bind_cmb_lif_ind', 'hav_car_grp_ind', 'hav_hou_grp_ind',
#        'l6mon_agn_ind', 'frs_agn_dt_cnt', 'vld_rsk_ases_ind',
#        'fin_rsk_ases_grd_cd', 'confirm_rsk_ases_lvl_typ_cd',
#        'cust_inv_rsk_endu_lvl_cd', 'l6mon_daim_aum_cd', 'tot_ast_lvl_cd',
#        'pot_ast_lvl_cd', 'bk1_cur_year_mon_avg_agn_amt_cd',
#        'l12mon_buy_fin_mng_whl_tms', 'l12_mon_fnd_buy_whl_tms',
#        'l12_mon_insu_buy_whl_tms', 'l12_mon_gld_buy_whl_tms', 'loan_act_ind',
#        'pl_crd_lmt_cd', 'ovd_30d_loan_tot_cnt', 'his_lng_ovd_day',
#        'hld_crd_card_grd_cd', 'crd_card_act_ind',
#        'l1y_crd_card_csm_amt_dlm_cd', 'atdd_type', 'perm_crd_lmt_cd',
#        'cur_debit_cnt', 'cur_credit_cnt', 'cur_debit_min_opn_dt_cnt',
#        'cur_credit_min_opn_dt_cnt', 'cur_debit_crd_lvl', 'flg1_trd_cnt_B',
#        'flg1_trd_cnt_C', 'trd_cnt', 'flg1_trd_cnt_B_precent',
#        'flg1_trd_cnt_C_precent', 'cny_trx_amt_B', 'cny_trx_amt_C',
#        'trx_amt_balance', 'trx_total_amount', 'cny_trx_amt_B_percent',
#        'cny_trx_amt_C_percent', 'trx_cod1_1_cnt', 'trx_cod1_2_cnt',
#        'trx_cod1_3_cnt', 'trx_cod1_cnt', 'trx_cod1_cnt_1_percent',
#        'trx_cod1_cnt_2_percent', 'trx_cod1_cnt_3_percent', 'trx_flg3_A_cnt',
#        'trx_flg3_B_cnt', 'trx_flg3_C_cnt', 'trd_flg3_cnt',
#        'trd_flg3_A_percent', 'trd_flg3_B_percent', 'trd_flg3_C_percent',
#        'beh_pred', 'beh_pred_mean', 'beh_pred_sum', 'trd_pred',
#        'trd_pred_mean', 'trd_pred_sum', 'age&gdr'],
#       dtype='object')

# %%
train_df.dtypes
# Out:
# gdr_cd                              object
# age                                 object
# mrg_situ_cd                         object
# edu_deg_cd                          object
# acdm_deg_cd                         object
# deg_cd                              object
# job_year                            object
# ic_ind                              object
# fr_or_sh_ind                        object
# dnl_mbl_bnk_ind                     object
# dnl_bind_cmb_lif_ind                object
# hav_car_grp_ind                     object
# hav_hou_grp_ind                     object
# l6mon_agn_ind                       object
# frs_agn_dt_cnt                      object
# vld_rsk_ases_ind                    object
# fin_rsk_ases_grd_cd                 object
# confirm_rsk_ases_lvl_typ_cd         object
# cust_inv_rsk_endu_lvl_cd            object
# l6mon_daim_aum_cd                    int64
# tot_ast_lvl_cd                      object
# pot_ast_lvl_cd                      object
# bk1_cur_year_mon_avg_agn_amt_cd      int64
# l12mon_buy_fin_mng_whl_tms          object
# l12_mon_fnd_buy_whl_tms             object
# l12_mon_insu_buy_whl_tms            object
# l12_mon_gld_buy_whl_tms             object
# loan_act_ind                        object
# pl_crd_lmt_cd                        int64
# ovd_30d_loan_tot_cnt                object
# his_lng_ovd_day                     object
# hld_crd_card_grd_cd                 object
# crd_card_act_ind                    object
# l1y_crd_card_csm_amt_dlm_cd         object
# atdd_type                           object
# perm_crd_lmt_cd                      int64
# cur_debit_cnt                        int64
# cur_credit_cnt                       int64
# cur_debit_min_opn_dt_cnt             int64
# cur_credit_min_opn_dt_cnt            int64
# cur_debit_crd_lvl                    int64
# flg1_trd_cnt_B                     float64
# flg1_trd_cnt_C                     float64
# trd_cnt                            float64
# flg1_trd_cnt_B_precent             float64
# flg1_trd_cnt_C_precent             float64
# cny_trx_amt_B                      float64
# cny_trx_amt_C                      float64
# trx_amt_balance                    float64
# trx_total_amount                   float64
# cny_trx_amt_B_percent              float64
# cny_trx_amt_C_percent              float64
# trx_cod1_1_cnt                     float64
# trx_cod1_2_cnt                     float64
# trx_cod1_3_cnt                     float64
# trx_cod1_cnt                       float64
# trx_cod1_cnt_1_percent             float64
# trx_cod1_cnt_2_percent             float64
# trx_cod1_cnt_3_percent             float64
# trx_flg3_A_cnt                     float64
# trx_flg3_B_cnt                     float64
# trx_flg3_C_cnt                     float64
# trd_flg3_cnt                       float64
# trd_flg3_A_percent                 float64
# trd_flg3_B_percent                 float64
# trd_flg3_C_percent                 float64
# beh_pred                           float64
# beh_pred_mean                      float64
# beh_pred_sum                       float64
# trd_pred                           float64
# trd_pred_mean                      float64
# trd_pred_sum                       float64
# age&gdr                             object
# dtype: object

# %%
def order_object_replace(col, val):
    train_df[col].replace({'\\N': val}, inplace = True)
    train_df[col] = train_df[col].astype('int64')
    test_df[col].replace({'\\N': val}, inplace = True)
    test_df[col] = test_df[col].astype('int64')

# %%
order_object_cols = ['job_year', 'frs_agn_dt_cnt', 'fin_rsk_ases_grd_cd', 'confirm_rsk_ases_lvl_typ_cd', 'cust_inv_rsk_endu_lvl_cd',
                    'tot_ast_lvl_cd', 'pot_ast_lvl_cd', 'l12mon_buy_fin_mng_whl_tms', 
                     'l12_mon_fnd_buy_whl_tms', 'l12_mon_insu_buy_whl_tms',
                    'l12_mon_gld_buy_whl_tms', 'ovd_30d_loan_tot_cnt',
                    'his_lng_ovd_day', 'hld_crd_card_grd_cd',
                    'l1y_crd_card_csm_amt_dlm_cd']

for col in order_object_cols:
    print(col)
    order_object_replace(col, -1)
# Out:
# job_year
# frs_agn_dt_cnt
# fin_rsk_ases_grd_cd
# confirm_rsk_ases_lvl_typ_cd
# cust_inv_rsk_endu_lvl_cd
# tot_ast_lvl_cd
# pot_ast_lvl_cd
# l12mon_buy_fin_mng_whl_tms
# l12_mon_fnd_buy_whl_tms
# l12_mon_insu_buy_whl_tms
# l12_mon_gld_buy_whl_tms
# ovd_30d_loan_tot_cnt
# his_lng_ovd_day
# hld_crd_card_grd_cd
# l1y_crd_card_csm_amt_dlm_cd

# %%
ind_object_cols = ['ic_ind', 'fr_or_sh_ind', 'dnl_mbl_bnk_ind',
       'dnl_bind_cmb_lif_ind', 'hav_car_grp_ind', 'hav_hou_grp_ind',
       'l6mon_agn_ind', 'vld_rsk_ases_ind', 'loan_act_ind',
       'crd_card_act_ind']

for col in ind_object_cols:
    print(col)
    order_object_replace(col, 0)
# Out:
# ic_ind
# fr_or_sh_ind
# dnl_mbl_bnk_ind
# dnl_bind_cmb_lif_ind
# hav_car_grp_ind
# hav_hou_grp_ind
# l6mon_agn_ind
# vld_rsk_ases_ind
# loan_act_ind
# crd_card_act_ind

# %%
train_df['deg_cd'].value_counts()
# Out:
# ~     17050
# \N      736
# A       543
# B       332
# Z       171
# C       118
# D        10
# Name: deg_cd, dtype: int64

# %%
train_df['edu_deg_cd'].fillna('\\N', inplace=True)
train_df['deg_cd'].fillna('\\N', inplace=True)
train_df['atdd_type'].fillna('\\N', inplace=True)
train_df['acdm_deg_cd'].fillna('\\N', inplace=True)

# %%
test_df['edu_deg_cd'].fillna('\\N', inplace=True)
test_df['deg_cd'].fillna('\\N', inplace=True)
test_df['atdd_type'].fillna('\\N', inplace=True)

# %%
train_df.replace({b'\N': 'None'}, inplace = True)
test_df.replace({b'\N': 'None'}, inplace = True)
train_df.replace({'\\N': 'None'}, inplace = True)
test_df.replace({'\\N': 'None'}, inplace = True)

# %%
test_df.replace({'atdd_type': 0.0}, '0', inplace=True)
test_df.replace({'atdd_type': 1.0}, '1', inplace=True)

# %%
from sklearn import preprocessing

label_object_cols = ['age', 'gdr_cd','mrg_situ_cd', 'edu_deg_cd', 'acdm_deg_cd', 'deg_cd','age&gdr', 'atdd_type']

for col in label_object_cols:
    print(col)
    le = preprocessing.LabelEncoder()
    le.fit(list(train_df[col]) + list(test_df[col]))
    train_df[col] = le.transform(train_df[col])
    test_df[col] = le.transform(test_df[col])
# Out:
# age
# gdr_cd
# mrg_situ_cd
# edu_deg_cd
# acdm_deg_cd
# deg_cd
# age&gdr
# atdd_type

# %%
train_df.dtypes
# Out:
# gdr_cd                               int64
# age                                  int64
# mrg_situ_cd                          int64
# edu_deg_cd                           int64
# acdm_deg_cd                          int64
# deg_cd                               int64
# job_year                             int64
# ic_ind                               int64
# fr_or_sh_ind                         int64
# dnl_mbl_bnk_ind                      int64
# dnl_bind_cmb_lif_ind                 int64
# hav_car_grp_ind                      int64
# hav_hou_grp_ind                      int64
# l6mon_agn_ind                        int64
# frs_agn_dt_cnt                       int64
# vld_rsk_ases_ind                     int64
# fin_rsk_ases_grd_cd                  int64
# confirm_rsk_ases_lvl_typ_cd          int64
# cust_inv_rsk_endu_lvl_cd             int64
# l6mon_daim_aum_cd                    int64
# tot_ast_lvl_cd                       int64
# pot_ast_lvl_cd                       int64
# bk1_cur_year_mon_avg_agn_amt_cd      int64
# l12mon_buy_fin_mng_whl_tms           int64
# l12_mon_fnd_buy_whl_tms              int64
# l12_mon_insu_buy_whl_tms             int64
# l12_mon_gld_buy_whl_tms              int64
# loan_act_ind                         int64
# pl_crd_lmt_cd                        int64
# ovd_30d_loan_tot_cnt                 int64
# his_lng_ovd_day                      int64
# hld_crd_card_grd_cd                  int64
# crd_card_act_ind                     int64
# l1y_crd_card_csm_amt_dlm_cd          int64
# atdd_type                            int64
# perm_crd_lmt_cd                      int64
# cur_debit_cnt                        int64
# cur_credit_cnt                       int64
# cur_debit_min_opn_dt_cnt             int64
# cur_credit_min_opn_dt_cnt            int64
# cur_debit_crd_lvl                    int64
# flg1_trd_cnt_B                     float64
# flg1_trd_cnt_C                     float64
# trd_cnt                            float64
# flg1_trd_cnt_B_precent             float64
# flg1_trd_cnt_C_precent             float64
# cny_trx_amt_B                      float64
# cny_trx_amt_C                      float64
# trx_amt_balance                    float64
# trx_total_amount                   float64
# cny_trx_amt_B_percent              float64
# cny_trx_amt_C_percent              float64
# trx_cod1_1_cnt                     float64
# trx_cod1_2_cnt                     float64
# trx_cod1_3_cnt                     float64
# trx_cod1_cnt                       float64
# trx_cod1_cnt_1_percent             float64
# trx_cod1_cnt_2_percent             float64
# trx_cod1_cnt_3_percent             float64
# trx_flg3_A_cnt                     float64
# trx_flg3_B_cnt                     float64
# trx_flg3_C_cnt                     float64
# trd_flg3_cnt                       float64
# trd_flg3_A_percent                 float64
# trd_flg3_B_percent                 float64
# trd_flg3_C_percent                 float64
# beh_pred                           float64
# beh_pred_mean                      float64
# beh_pred_sum                       float64
# trd_pred                           float64
# trd_pred_mean                      float64
# trd_pred_sum                       float64
# age&gdr                              int64
# dtype: object

# %%
test_df.dtypes
# Out:
# gdr_cd                               int64
# age                                  int64
# mrg_situ_cd                          int64
# edu_deg_cd                           int64
# acdm_deg_cd                          int64
# deg_cd                               int64
# job_year                             int64
# ic_ind                               int64
# fr_or_sh_ind                         int64
# dnl_mbl_bnk_ind                      int64
# dnl_bind_cmb_lif_ind                 int64
# hav_car_grp_ind                      int64
# hav_hou_grp_ind                      int64
# l6mon_agn_ind                        int64
# frs_agn_dt_cnt                       int64
# vld_rsk_ases_ind                     int64
# fin_rsk_ases_grd_cd                  int64
# confirm_rsk_ases_lvl_typ_cd          int64
# cust_inv_rsk_endu_lvl_cd             int64
# l6mon_daim_aum_cd                    int64
# tot_ast_lvl_cd                       int64
# pot_ast_lvl_cd                       int64
# bk1_cur_year_mon_avg_agn_amt_cd      int64
# l12mon_buy_fin_mng_whl_tms           int64
# l12_mon_fnd_buy_whl_tms              int64
# l12_mon_insu_buy_whl_tms             int64
# l12_mon_gld_buy_whl_tms              int64
# loan_act_ind                         int64
# pl_crd_lmt_cd                        int64
# ovd_30d_loan_tot_cnt                 int64
# his_lng_ovd_day                      int64
# hld_crd_card_grd_cd                  int64
# crd_card_act_ind                     int64
# l1y_crd_card_csm_amt_dlm_cd          int64
# atdd_type                            int64
# perm_crd_lmt_cd                      int64
# cur_debit_cnt                        int64
# cur_credit_cnt                       int64
# cur_debit_min_opn_dt_cnt             int64
# cur_credit_min_opn_dt_cnt            int64
# cur_debit_crd_lvl                    int64
# flg1_trd_cnt_B                     float64
# flg1_trd_cnt_C                     float64
# trd_cnt                            float64
# flg1_trd_cnt_B_precent             float64
# flg1_trd_cnt_C_precent             float64
# cny_trx_amt_B                      float64
# cny_trx_amt_C                      float64
# trx_amt_balance                    float64
# trx_total_amount                   float64
# cny_trx_amt_B_percent              float64
# cny_trx_amt_C_percent              float64
# trx_cod1_1_cnt                     float64
# trx_cod1_2_cnt                     float64
# trx_cod1_3_cnt                     float64
# trx_cod1_cnt                       float64
# trx_cod1_cnt_1_percent             float64
# trx_cod1_cnt_2_percent             float64
# trx_cod1_cnt_3_percent             float64
# trx_flg3_A_cnt                     float64
# trx_flg3_B_cnt                     float64
# trx_flg3_C_cnt                     float64
# trd_flg3_cnt                       float64
# trd_flg3_A_percent                 float64
# trd_flg3_B_percent                 float64
# trd_flg3_C_percent                 float64
# beh_pred                           float64
# beh_pred_mean                      float64
# beh_pred_sum                       float64
# trd_pred                           float64
# trd_pred_mean                      float64
# trd_pred_sum                       float64
# age&gdr                              int64
# dtype: object

# %%
test_df.isnull().sum()
# Out:
# gdr_cd                                0
# age                                   0
# mrg_situ_cd                           0
# edu_deg_cd                            0
# acdm_deg_cd                           0
# deg_cd                                0
# job_year                              0
# ic_ind                                0
# fr_or_sh_ind                          0
# dnl_mbl_bnk_ind                       0
# dnl_bind_cmb_lif_ind                  0
# hav_car_grp_ind                       0
# hav_hou_grp_ind                       0
# l6mon_agn_ind                         0
# frs_agn_dt_cnt                        0
# vld_rsk_ases_ind                      0
# fin_rsk_ases_grd_cd                   0
# confirm_rsk_ases_lvl_typ_cd           0
# cust_inv_rsk_endu_lvl_cd              0
# l6mon_daim_aum_cd                     0
# tot_ast_lvl_cd                        0
# pot_ast_lvl_cd                        0
# bk1_cur_year_mon_avg_agn_amt_cd       0
# l12mon_buy_fin_mng_whl_tms            0
# l12_mon_fnd_buy_whl_tms               0
# l12_mon_insu_buy_whl_tms              0
# l12_mon_gld_buy_whl_tms               0
# loan_act_ind                          0
# pl_crd_lmt_cd                         0
# ovd_30d_loan_tot_cnt                  0
# his_lng_ovd_day                       0
# hld_crd_card_grd_cd                   0
# crd_card_act_ind                      0
# l1y_crd_card_csm_amt_dlm_cd           0
# atdd_type                             0
# perm_crd_lmt_cd                       0
# cur_debit_cnt                         0
# cur_credit_cnt                        0
# cur_debit_min_opn_dt_cnt              0
# cur_credit_min_opn_dt_cnt             0
# cur_debit_crd_lvl                     0
# flg1_trd_cnt_B                      810
# flg1_trd_cnt_C                      810
# trd_cnt                             810
# flg1_trd_cnt_B_precent              810
# flg1_trd_cnt_C_precent              810
# cny_trx_amt_B                      1046
# cny_trx_amt_C                       972
# trx_amt_balance                    1208
# trx_total_amount                   1208
# cny_trx_amt_B_percent              1208
# cny_trx_amt_C_percent              1208
# trx_cod1_1_cnt                     1105
# trx_cod1_2_cnt                     2137
# trx_cod1_3_cnt                     1139
# trx_cod1_cnt                       2428
# trx_cod1_cnt_1_percent             2428
# trx_cod1_cnt_2_percent             2428
# trx_cod1_cnt_3_percent             2428
# trx_flg3_A_cnt                      810
# trx_flg3_B_cnt                      810
# trx_flg3_C_cnt                      810
# trd_flg3_cnt                        810
# trd_flg3_A_percent                  810
# trd_flg3_B_percent                  810
# trd_flg3_C_percent                  810
# beh_pred                           2768
# beh_pred_mean                      2768
# beh_pred_sum                       2768
# trd_pred                            810
# trd_pred_mean                       810
# trd_pred_sum                        810
# age&gdr                               0
# dtype: int64

# %%
test_df['atdd_type'].value_counts()
# Out:
# 2    2356
# 0    1529
# 1     115
# Name: atdd_type, dtype: int64

# %%
n_splits = 20
random_state = 2020
# np.random.seed(random_state)
splits = list(StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state).split(train_df, train_target))

cols = list(train_df.columns)
sparse_features = ['age', 'gdr_cd','mrg_situ_cd', 'edu_deg_cd', 'acdm_deg_cd', 'deg_cd',
        'ic_ind', 'fr_or_sh_ind', 'dnl_mbl_bnk_ind',
       'dnl_bind_cmb_lif_ind', 'hav_car_grp_ind', 'hav_hou_grp_ind',
       'l6mon_agn_ind', 'vld_rsk_ases_ind',
       'fin_rsk_ases_grd_cd', 'confirm_rsk_ases_lvl_typ_cd',
       'cust_inv_rsk_endu_lvl_cd', 'l6mon_daim_aum_cd', 'tot_ast_lvl_cd',
       'pot_ast_lvl_cd', 'bk1_cur_year_mon_avg_agn_amt_cd',
       'loan_act_ind',
       'pl_crd_lmt_cd',
       'hld_crd_card_grd_cd', 'crd_card_act_ind',
       'l1y_crd_card_csm_amt_dlm_cd', 'atdd_type', 'perm_crd_lmt_cd',
       'cur_debit_crd_lvl', 'age&gdr']

feature_importance_df = pd.DataFrame()
oof = np.zeros(len(train_df))
predictions = np.zeros(len(test_df))

# %%
for i, (train_idx, valid_idx) in enumerate(splits):
    print('Folder', i)
    x_tr, y_tr = train_df.iloc[train_idx], train_target.iloc[train_idx]
    x_valid, y_valid = train_df.iloc[valid_idx], train_target.iloc[valid_idx]
    
    # x_tr, y_tr = augment(x_tr, y_tr, cols)
    num_round = 100000  
    clf = cat.CatBoostClassifier(iterations=num_round, depth=7,\
                                 l2_leaf_reg=4, learning_rate=0.05, verbose=1000, \
                                 loss_function='Logloss', eval_metric='AUC', \
                                early_stopping_rounds=2000, random_seed=random_state, \
                                task_type='GPU', devices='2',\
                                 cat_features=sparse_features,\
                                 bootstrap_type='Poisson', subsample=0.99)
    
    clf.fit(x_tr, y_tr, eval_set=cat.Pool(x_valid, y_valid, cat_features=sparse_features))
    
    print(f'best score {clf.get_best_score()}')
    print(f'best_iteration {clf.get_best_iteration()}')
    oof[valid_idx] = clf.predict_proba(x_valid)[:, 1]
    predictions += clf.predict_proba(test_df)[:, 1] / n_splits
    del x_tr
    del y_tr
    
print(metrics.roc_auc_score(train_target.values, oof))
# Out:
# Folder 0
# 0:	learn: 0.7263142	test: 0.7395281	best: 0.7395281 (0)	total: 2.77s	remaining: 3d 5h 2s
# 1000:	learn: 0.8299178	test: 0.7837401	best: 0.7840124 (980)	total: 1m 52s	remaining: 3h 4m 38s
# 2000:	learn: 0.8513774	test: 0.7863166	best: 0.7865458 (1928)	total: 3m 51s	remaining: 3h 9m 6s
# 3000:	learn: 0.8676453	test: 0.7878441	best: 0.7882174 (2795)	total: 5m 47s	remaining: 3h 7m 23s
# 4000:	learn: 0.8794736	test: 0.7871798	best: 0.7882174 (2795)	total: 7m 46s	remaining: 3h 6m 25s
# bestTest = 0.7882173657
# bestIteration = 2795
# Shrink model to first 2796 iterations.
# best score {'learn': {'Logloss': 0.3455134824642066, 'AUC': 0.8873098492622375}, 'validation': {'Logloss': 0.4201021075069636, 'AUC': 0.7882173657417297}}
# best_iteration 2795
# Folder 1
# 0:	learn: 0.7037722	test: 0.7217452	best: 0.7217452 (0)	total: 149ms	remaining: 4h 8m 56s
# 1000:	learn: 0.8314540	test: 0.7716442	best: 0.7716442 (1000)	total: 2m 4s	remaining: 3h 25m 6s
# 2000:	learn: 0.8515268	test: 0.7718589	best: 0.7719381 (1984)	total: 4m 6s	remaining: 3h 21m 2s
# 3000:	learn: 0.8651766	test: 0.7719784	best: 0.7730722 (2408)	total: 6m 4s	remaining: 3h 16m 6s
# 4000:	learn: 0.8736899	test: 0.7716701	best: 0.7730722 (2408)	total: 7m 56s	remaining: 3h 10m 34s
# bestTest = 0.7730721831
# bestIteration = 2408
# Shrink model to first 2409 iterations.
# best score {'learn': {'Logloss': 0.3547041545542636, 'AUC': 0.8767560124397278}, 'validation': {'Logloss': 0.42667843928979404, 'AUC': 0.7730721831321716}}
# best_iteration 2408
# Folder 2
# 0:	learn: 0.7140207	test: 0.7144096	best: 0.7144096 (0)	total: 101ms	remaining: 2h 47m 38s
# 1000:	learn: 0.8351289	test: 0.7671568	best: 0.7683946 (588)	total: 1m 40s	remaining: 2h 45m 25s
# 2000:	learn: 0.8587719	test: 0.7656625	best: 0.7683946 (588)	total: 3m 18s	remaining: 2h 41m 44s
# bestTest = 0.768394649
# bestIteration = 588
# Shrink model to first 589 iterations.
# best score {'learn': {'Logloss': 0.36339730144722615, 'AUC': 0.8695559501647949}, 'validation': {'Logloss': 0.4359968602806554, 'AUC': 0.7683946490287781}}
# best_iteration 588
# Folder 3
# 0:	learn: 0.7275277	test: 0.7256907	best: 0.7256907 (0)	total: 111ms	remaining: 3h 5m 23s
# 1000:	learn: 0.8307922	test: 0.7856379	best: 0.7858685 (838)	total: 1m 40s	remaining: 2h 46m 17s
# 2000:	learn: 0.8549435	test: 0.7855673	best: 0.7859578 (1842)	total: 3m 19s	remaining: 2h 42m 50s
# 3000:	learn: 0.8705652	test: 0.7850140	best: 0.7859578 (1842)	total: 4m 56s	remaining: 2h 39m 51s
# bestTest = 0.7859578133
# bestIteration = 1842
# Shrink model to first 1843 iterations.
# best score {'learn': {'Logloss': 0.35149964630958974, 'AUC': 0.8803101181983948}, 'validation': {'Logloss': 0.43456951785099523, 'AUC': 0.7859578132629395}}
# best_iteration 1842
# Folder 4
# 0:	learn: 0.7202990	test: 0.7049774	best: 0.7049774 (0)	total: 103ms	remaining: 2h 52m 18s
# 1000:	learn: 0.8296104	test: 0.7613682	best: 0.7615289 (898)	total: 1m 40s	remaining: 2h 45m 24s
# 2000:	learn: 0.8544429	test: 0.7616363	best: 0.7616363 (1998)	total: 3m 17s	remaining: 2h 41m 24s
# 3000:	learn: 0.8682607	test: 0.7606405	best: 0.7619576 (2236)	total: 4m 53s	remaining: 2h 38m 12s
# 4000:	learn: 0.8765340	test: 0.7605540	best: 0.7619576 (2236)	total: 6m 29s	remaining: 2h 35m 37s
# bestTest = 0.7619575858
# bestIteration = 2236
# Shrink model to first 2237 iterations.
# best score {'learn': {'Logloss': 0.35311671907134945, 'AUC': 0.8785048723220825}, 'validation': {'Logloss': 0.4413585710597146, 'AUC': 0.761957585811615}}
# best_iteration 2236
# Folder 5
# 0:	learn: 0.7315938	test: 0.7256323	best: 0.7256323 (0)	total: 110ms	remaining: 3h 3m 26s
# 1000:	learn: 0.8343306	test: 0.7642560	best: 0.7644758 (838)	total: 1m 39s	remaining: 2h 44m 46s
# 2000:	learn: 0.8568368	test: 0.7636047	best: 0.7646509 (1509)	total: 3m 17s	remaining: 2h 41m 1s
# 3000:	learn: 0.8734851	test: 0.7626796	best: 0.7646509 (1509)	total: 4m 54s	remaining: 2h 38m 42s
# bestTest = 0.7646508813
# bestIteration = 1509
# Shrink model to first 1510 iterations.
# best score {'learn': {'Logloss': 0.352378928497271, 'AUC': 0.8806224763393402}, 'validation': {'Logloss': 0.4388884963186968, 'AUC': 0.7646508812904358}}
# best_iteration 1509
# Folder 6
# 0:	learn: 0.7260128	test: 0.7101558	best: 0.7101558 (0)	total: 129ms	remaining: 3h 34m 33s
# 1000:	learn: 0.8299666	test: 0.7663916	best: 0.7667130 (988)	total: 1m 39s	remaining: 2h 44m 21s
# 2000:	learn: 0.8551179	test: 0.7664954	best: 0.7667994 (1127)	total: 3m 17s	remaining: 2h 41m
# 3000:	learn: 0.8711897	test: 0.7649246	best: 0.7673975 (2283)	total: 4m 53s	remaining: 2h 38m 15s
# 4000:	learn: 0.8809644	test: 0.7646220	best: 0.7673975 (2283)	total: 6m 29s	remaining: 2h 35m 36s
# bestTest = 0.7673974633
# bestIteration = 2283
# Shrink model to first 2284 iterations.
# best score {'learn': {'Logloss': 0.349550950164465, 'AUC': 0.8830835223197937}, 'validation': {'Logloss': 0.4448087536578305, 'AUC': 0.7673974633216858}}
# best_iteration 2283
# Folder 7
# 0:	learn: 0.7265415	test: 0.7218201	best: 0.7218201 (0)	total: 125ms	remaining: 3h 27m 54s
# 1000:	learn: 0.8278740	test: 0.7557086	best: 0.7563225 (774)	total: 1m 40s	remaining: 2h 45m 24s
# 2000:	learn: 0.8523689	test: 0.7554247	best: 0.7565660 (1497)	total: 3m 17s	remaining: 2h 41m 10s
# 3000:	learn: 0.8679129	test: 0.7553138	best: 0.7565660 (1497)	total: 4m 53s	remaining: 2h 38m 12s
# bestTest = 0.7565660179
# bestIteration = 1497
# Shrink model to first 1498 iterations.
# best score {'learn': {'Logloss': 0.3588179170044956, 'AUC': 0.8735936284065247}, 'validation': {'Logloss': 0.44310976352223647, 'AUC': 0.7565660178661346}}
# best_iteration 1497
# Folder 8
# 0:	learn: 0.7124553	test: 0.7105564	best: 0.7105564 (0)	total: 124ms	remaining: 3h 25m 59s
# 1000:	learn: 0.8346267	test: 0.7601044	best: 0.7605238 (942)	total: 1m 40s	remaining: 2h 45m 45s
# 2000:	learn: 0.8539998	test: 0.7612746	best: 0.7615123 (1906)	total: 3m 15s	remaining: 2h 39m 41s
# 3000:	learn: 0.8667084	test: 0.7611780	best: 0.7618927 (2667)	total: 4m 50s	remaining: 2h 36m 23s
# 4000:	learn: 0.8747534	test: 0.7613394	best: 0.7621781 (3715)	total: 6m 23s	remaining: 2h 33m 31s
# 5000:	learn: 0.8826731	test: 0.7609172	best: 0.7621781 (3715)	total: 7m 57s	remaining: 2h 31m 14s
# bestTest = 0.7621780634
# bestIteration = 3715
# Shrink model to first 3716 iterations.
# best score {'learn': {'Logloss': 0.344624647339556, 'AUC': 0.8878613412380219}, 'validation': {'Logloss': 0.4424280158030014, 'AUC': 0.7621780633926392}}
# best_iteration 3715
# Folder 9
# 0:	learn: 0.7125045	test: 0.7105852	best: 0.7105852 (0)	total: 105ms	remaining: 2h 55m 20s
# 1000:	learn: 0.8375342	test: 0.7786576	best: 0.7792643 (493)	total: 1m 40s	remaining: 2h 45m 44s
# 2000:	learn: 0.8615834	test: 0.7769125	best: 0.7792643 (493)	total: 3m 18s	remaining: 2h 42m 20s
# bestTest = 0.7792642713
# bestIteration = 493
# Shrink model to first 494 iterations.
# best score {'learn': {'Logloss': 0.36325720028806097, 'AUC': 0.8693963885307312}, 'validation': {'Logloss': 0.4290197808920412, 'AUC': 0.7792642712593079}}
# best_iteration 493
# Folder 10
# 0:	learn: 0.7292847	test: 0.7163700	best: 0.7163700 (0)	total: 112ms	remaining: 3h 6m 30s
# 1000:	learn: 0.8350795	test: 0.7581557	best: 0.7600619 (492)	total: 1m 40s	remaining: 2h 46m 21s
# 2000:	learn: 0.8543972	test: 0.7569877	best: 0.7600619 (492)	total: 3m 18s	remaining: 2h 41m 46s
# bestTest = 0.7600619197
# bestIteration = 492
# Shrink model to first 493 iterations.
# best score {'learn': {'Logloss': 0.3718826061002057, 'AUC': 0.8596963286399841}, 'validation': {'Logloss': 0.44492096986942636, 'AUC': 0.7600619196891785}}
# best_iteration 492
# Folder 11
# 0:	learn: 0.7182868	test: 0.6942274	best: 0.6942274 (0)	total: 100ms	remaining: 2h 47m 28s
# 1000:	learn: 0.8318894	test: 0.7538327	best: 0.7557404 (531)	total: 1m 39s	remaining: 2h 44m 4s
# 2000:	learn: 0.8556519	test: 0.7528954	best: 0.7557404 (531)	total: 3m 28s	remaining: 2h 49m 57s
# bestTest = 0.7557404041
# bestIteration = 531
# Shrink model to first 532 iterations.
# best score {'learn': {'Logloss': 0.36799752134857755, 'AUC': 0.8644967079162598}, 'validation': {'Logloss': 0.44251576884237226, 'AUC': 0.7557404041290283}}
# best_iteration 531
# Folder 12
# 0:	learn: 0.7147799	test: 0.7065057	best: 0.7065057 (0)	total: 150ms	remaining: 4h 9m 50s
# 1000:	learn: 0.8219976	test: 0.7585587	best: 0.7585602 (995)	total: 2m 48s	remaining: 4h 37m 10s
# 2000:	learn: 0.8401100	test: 0.7589437	best: 0.7598507 (1973)	total: 5m 29s	remaining: 4h 28m 46s
# 3000:	learn: 0.8581232	test: 0.7580497	best: 0.7598507 (1973)	total: 8m 14s	remaining: 4h 26m 33s
# bestTest = 0.7598506808
# bestIteration = 1973
# Shrink model to first 1974 iterations.
# best score {'learn': {'Logloss': 0.36196792316489573, 'AUC': 0.8697481155395508}, 'validation': {'Logloss': 0.4420929260865481, 'AUC': 0.7598506808280945}}
# best_iteration 1973
# Folder 13
# 0:	learn: 0.7076861	test: 0.7110503	best: 0.7110503 (0)	total: 143ms	remaining: 3h 58m 45s
# 1000:	learn: 0.8377216	test: 0.7775581	best: 0.7776795 (868)	total: 2m 29s	remaining: 4h 6m 23s
# 2000:	learn: 0.8585714	test: 0.7763253	best: 0.7780712 (1241)	total: 4m 7s	remaining: 3h 21m 46s
# 3000:	learn: 0.8738740	test: 0.7741880	best: 0.7780712 (1241)	total: 5m 44s	remaining: 3h 5m 35s
# bestTest = 0.7780711651
# bestIteration = 1241
# Shrink model to first 1242 iterations.
# best score {'learn': {'Logloss': 0.35627509380437933, 'AUC': 0.8766878843307495}, 'validation': {'Logloss': 0.4325711128406955, 'AUC': 0.7780711650848389}}
# best_iteration 1241
# Folder 14
# 0:	learn: 0.7335862	test: 0.7345995	best: 0.7345995 (0)	total: 119ms	remaining: 3h 18m 22s
# 1000:	learn: 0.8267162	test: 0.7707166	best: 0.7711328 (859)	total: 1m 39s	remaining: 2h 44m 15s
# 2000:	learn: 0.8487350	test: 0.7699449	best: 0.7711328 (859)	total: 3m 16s	remaining: 2h 40m 17s
# bestTest = 0.7711328268
# bestIteration = 859
# Shrink model to first 860 iterations.
# best score {'learn': {'Logloss': 0.3701406952399942, 'AUC': 0.8611263036727905}, 'validation': {'Logloss': 0.432101249216792, 'AUC': 0.7711328268051147}}
# best_iteration 859
# Folder 15
# 0:	learn: 0.7334709	test: 0.7233357	best: 0.7233357 (0)	total: 106ms	remaining: 2h 57m 29s
# 1000:	learn: 0.8389576	test: 0.7722442	best: 0.7734307 (402)	total: 1m 40s	remaining: 2h 45m 52s
# 2000:	learn: 0.8621367	test: 0.7734914	best: 0.7737385 (1977)	total: 3m 18s	remaining: 2h 42m 4s
# 3000:	learn: 0.8772827	test: 0.7726228	best: 0.7737660 (2069)	total: 4m 55s	remaining: 2h 39m 7s
# 4000:	learn: 0.8884425	test: 0.7723121	best: 0.7737660 (2069)	total: 6m 31s	remaining: 2h 36m 38s
# bestTest = 0.7737659812
# bestIteration = 2069
# Shrink model to first 2070 iterations.
# best score {'learn': {'Logloss': 0.34371351536958183, 'AUC': 0.8893635272979736}, 'validation': {'Logloss': 0.43804644056430136, 'AUC': 0.7737659811973572}}
# best_iteration 2069
# Folder 16
# 0:	learn: 0.7190163	test: 0.7080378	best: 0.7080378 (0)	total: 143ms	remaining: 3h 58m 45s
# 1000:	learn: 0.8276321	test: 0.7720809	best: 0.7721083 (999)	total: 1m 38s	remaining: 2h 42m 12s
# 2000:	learn: 0.8531063	test: 0.7744148	best: 0.7747111 (1655)	total: 3m 15s	remaining: 2h 39m 28s
# 3000:	learn: 0.8691760	test: 0.7768933	best: 0.7774237 (2894)	total: 4m 52s	remaining: 2h 37m 19s
# 4000:	learn: 0.8814533	test: 0.7778530	best: 0.7779208 (3994)	total: 6m 28s	remaining: 2h 35m 22s
# 5000:	learn: 0.8909076	test: 0.7769613	best: 0.7779208 (3994)	total: 8m 4s	remaining: 2h 33m 25s
# bestTest = 0.7779208422
# bestIteration = 3994
# Shrink model to first 3995 iterations.
# best score {'learn': {'Logloss': 0.3322946242304498, 'AUC': 0.8985769748687744}, 'validation': {'Logloss': 0.43020007293624685, 'AUC': 0.7779208421707153}}
# best_iteration 3994
# Folder 17
# 0:	learn: 0.7265216	test: 0.7234571	best: 0.7234571 (0)	total: 110ms	remaining: 3h 3m 17s
# 1000:	learn: 0.8321609	test: 0.7730607	best: 0.7732443 (952)	total: 1m 39s	remaining: 2h 43m 39s
# 2000:	learn: 0.8544439	test: 0.7728671	best: 0.7737833 (1095)	total: 3m 15s	remaining: 2h 39m 54s
# 3000:	learn: 0.8706282	test: 0.7722558	best: 0.7737833 (1095)	total: 4m 52s	remaining: 2h 37m 38s
# bestTest = 0.7737833261
# bestIteration = 1095
# Shrink model to first 1096 iterations.
# best score {'learn': {'Logloss': 0.36214445895018194, 'AUC': 0.8715163171291351}, 'validation': {'Logloss': 0.42717624750352445, 'AUC': 0.7737833261489868}}
# best_iteration 1095
# Folder 18
# 0:	learn: 0.7220193	test: 0.7155390	best: 0.7155390 (0)	total: 100ms	remaining: 2h 47m 10s
# 1000:	learn: 0.8308636	test: 0.7481950	best: 0.7516171 (299)	total: 1m 39s	remaining: 2h 44m 46s
# 2000:	learn: 0.8537466	test: 0.7474276	best: 0.7516171 (299)	total: 3m 17s	remaining: 2h 40m 59s
# bestTest = 0.7516171336
# bestIteration = 299
# Shrink model to first 300 iterations.
# best score {'learn': {'Logloss': 0.37378529611204125, 'AUC': 0.8586934208869934}, 'validation': {'Logloss': 0.44863470933192356, 'AUC': 0.7516171336174011}}
# best_iteration 299
# Folder 19
# 0:	learn: 0.7194520	test: 0.7011313	best: 0.7011313 (0)	total: 122ms	remaining: 3h 22m 53s
# 1000:	learn: 0.8319985	test: 0.7636085	best: 0.7637935 (982)	total: 1m 40s	remaining: 2h 44m 58s
# 2000:	learn: 0.8564901	test: 0.7651448	best: 0.7651448 (2000)	total: 3m 17s	remaining: 2h 41m
# 3000:	learn: 0.8719983	test: 0.7645782	best: 0.7662272 (2712)	total: 4m 53s	remaining: 2h 38m 21s
# 4000:	learn: 0.8804622	test: 0.7646151	best: 0.7662272 (2712)	total: 6m 30s	remaining: 2h 36m 3s
# bestTest = 0.7662271857
# bestIteration = 2712
# Shrink model to first 2713 iterations.
# best score {'learn': {'Logloss': 0.3458699964818208, 'AUC': 0.8866857886314392}, 'validation': {'Logloss': 0.43723939976895365, 'AUC': 0.7662271857261658}}
# best_iteration 2712
# 0.7686596231509428

# %%
import os

with open(os.path.join('result','catboost_oof_test_76865.txt'), 'w+') as f:
    for tid, pred in zip(test_id, predictions):
        f.write('{}\t{}\n'.format(tid, pred))

# %%
submission = pd.DataFrame({'ID': test_id, 'flag': predictions})
oof = pd.DataFrame({'flag': oof})

# %%
submission.to_csv('test_result/catboost_oof_test_76865.csv', index = False)
oof.to_csv('train_result/catboost_oof_train_76865.csv')

# %%
feature_importance_df = pd.DataFrame({'column': train_df.columns.values, 'score': clf.get_feature_importance()})
feature_importance_df.sort_values(by = ['score'], ascending=False)
# Out:
#                              column    score
# 70                    trd_pred_mean 11.34951
# 67                    beh_pred_mean  5.09520
# 33      l1y_crd_card_csm_amt_dlm_cd  4.60944
# 69                         trd_pred  3.41794
# 35                  perm_crd_lmt_cd  3.33810
# 39        cur_credit_min_opn_dt_cnt  2.79201
# 68                     beh_pred_sum  2.77774
# 47                    cny_trx_amt_C  2.68625
# 72                          age&gdr  2.54745
# 46                    cny_trx_amt_B  2.48540
# 31              hld_crd_card_grd_cd  2.20799
# 42                   flg1_trd_cnt_C  2.19435
# 4                       acdm_deg_cd  2.08475
# 21                   pot_ast_lvl_cd  1.87296
# 5                            deg_cd  1.76917
# 66                         beh_pred  1.72052
# 50            cny_trx_amt_B_percent  1.69485
# 2                       mrg_situ_cd  1.66646
# 38         cur_debit_min_opn_dt_cnt  1.65276
# 51            cny_trx_amt_C_percent  1.63729
# 3                        edu_deg_cd  1.62532
# 20                   tot_ast_lvl_cd  1.59438
# 63               trd_flg3_A_percent  1.56705
# 64               trd_flg3_B_percent  1.56145
# 1                               age  1.54089
# 49                 trx_total_amount  1.47113
# 57           trx_cod1_cnt_2_percent  1.46573
# 0                            gdr_cd  1.46067
# 16              fin_rsk_ases_grd_cd  1.43168
# 52                   trx_cod1_1_cnt  1.42316
# 44           flg1_trd_cnt_B_precent  1.29995
# 17      confirm_rsk_ases_lvl_typ_cd  1.29202
# 56           trx_cod1_cnt_1_percent  1.22128
# 60                   trx_flg3_B_cnt  1.21788
# 19                l6mon_daim_aum_cd  1.18952
# 6                          job_year  1.10322
# 34                        atdd_type  1.06378
# 71                     trd_pred_sum  0.99220
# 40                cur_debit_crd_lvl  0.97416
# 59                   trx_flg3_A_cnt  0.97196
# 18         cust_inv_rsk_endu_lvl_cd  0.87371
# 48                  trx_amt_balance  0.86742
# 22  bk1_cur_year_mon_avg_agn_amt_cd  0.79626
# 28                    pl_crd_lmt_cd  0.75527
# 14                   frs_agn_dt_cnt  0.74220
# 37                   cur_credit_cnt  0.73370
# 11                  hav_car_grp_ind  0.69673
# 54                   trx_cod1_3_cnt  0.68015
# 53                   trx_cod1_2_cnt  0.66410
# 10             dnl_bind_cmb_lif_ind  0.66390
# 45           flg1_trd_cnt_C_precent  0.65853
# 58           trx_cod1_cnt_3_percent  0.60104
# 8                      fr_or_sh_ind  0.57616
# 61                   trx_flg3_C_cnt  0.52942
# 30                  his_lng_ovd_day  0.47404
# 55                     trx_cod1_cnt  0.45676
# 32                 crd_card_act_ind  0.45456
# 23       l12mon_buy_fin_mng_whl_tms  0.43809
# 65               trd_flg3_C_percent  0.39737
# 24          l12_mon_fnd_buy_whl_tms  0.36771
# 9                   dnl_mbl_bnk_ind  0.33513
# 36                    cur_debit_cnt  0.33216
# 41                   flg1_trd_cnt_B  0.23064
# 43                          trd_cnt  0.19247
# 29             ovd_30d_loan_tot_cnt  0.09672
# 27                     loan_act_ind  0.09254
# 7                            ic_ind  0.07530
# 62                     trd_flg3_cnt  0.05673
# 15                 vld_rsk_ases_ind  0.03462
# 12                  hav_hou_grp_ind  0.02765
# 26          l12_mon_gld_buy_whl_tms  0.01823
# 13                    l6mon_agn_ind  0.01176
# 25         l12_mon_insu_buy_whl_tms  0.00135
